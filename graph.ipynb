# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
columns = ['Measurement_id', 'Sensor_id', 'Weight', 'Timestamp', 'A4', 'A7', 'B4', 'B7', 'A5', 'A6', 'B5', 'B6', 'A0', 'A3', 'B0', 'B3', 'A1', 'A2', 'B1', 'B2', 'MISTAKE']

df = pd.read_csv('sensor_A0.csv')
df.columns = columns
test = df[(df.Measurement_id == 4) & (df.Weight == 200)]

plt.scatter(test.Timestamp, test.A0)
plt.show()

# %%
base = pd.read_csv('sensor_ empty.csv')
base.columns = columns
base.head()
# Out:
#      Measurement_id Sensor_id  Weight                   Timestamp  \
# 114               5     empty       0  2024-02-19 14:03:36.319125
# 115               5     empty       0  2024-02-19 14:03:36.864808
# 116               5     empty       0  2024-02-19 14:03:37.409110
# 117               5     empty       0  2024-02-19 14:03:37.954045
# 118               5     empty       0  2024-02-19 14:03:38.499377
#
#               A4           A7           B4           B7           A5  \
# 114  151867520.0  151361232.0  152652528.0  153563216.0  150910880.0
# 115  151867392.0  151361008.0  152652528.0  153563216.0  150911408.0
# 116  151867696.0  151361584.0  152652240.0  153563216.0  150911408.0
# 117  151867520.0  151360944.0  152652816.0  153563216.0  150911424.0
# 118  151867808.0  151361440.0  152651952.0  153563216.0  150911424.0
#
#               A6  ...           B6           A0           A3           B0  \
# 114  153659808.0  ...  152503248.0  151662496.0  151977504.0  154853184.0
# ...

# %%
b= base["A0"].mean()

# %%
A0_200g=df[df["Weight"]==200]["A0"].mean()
A0_2g=df[df["Weight"]==2.4]["A0"].mean()

print(b-A0_200g, b-A0_2g)
# Out:
# 135687.38016808033 3426.4201680719852
